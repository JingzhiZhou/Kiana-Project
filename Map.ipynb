# %% [markdown]
# <a href="https://colab.research.google.com/github/JingzhiZhou/Kiana-Project/blob/main/Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Aug = pd.read_csv("/content/gdrive/MyDrive/3 x Zones Group Assignment/Present1_data/rio_aug.csv")

# %%
equip = pd.read_csv("/content/gdrive/MyDrive/3 x Zones Group Assignment/Present1_data/tps1_level2_equip.csv")

# %%
a = equip.groupby(['MAC']).size().to_frame('counts').reset_index()

# %%
b = a['MAC'].to_list()
c = Aug[~Aug.MAC.isin(b)]
c
# Out:
#         Building    Level  ...          Time        Date
# 0           TPS1  Level 2  ...  02:52:33.289  2019-08-01
# 1           TPS1  Level 2  ...  02:52:35.488  2019-08-01
# 2           TPS1  Level 2  ...  02:52:36.268  2019-08-01
# 5           TPS1  Level 2  ...   02:52:41.54  2019-08-01
# 6           TPS1  Level 2  ...  02:52:43.281  2019-08-01
# ...          ...      ...  ...           ...         ...
# 4807255     TPS1  Level 2  ...  23:59:12.949  2019-08-31
# 4807257     TPS1  Level 2  ...  23:59:14.531  2019-08-31
# 4807259     TPS1  Level 2  ...  23:59:14.678  2019-08-31
# 4807260     TPS1  Level 2  ...  23:59:16.145  2019-08-31
# 4807261     TPS1  Level 2  ...  23:59:16.371  2019-08-31
#
# [4191682 rows x 7 columns]

# %%
t8 = c.loc[c['Time'].str.startswith('23:00')].copy()
t8[t8['Date']=="2019-08-01"]
# Out:
#        Building    Level  ...          Time        Date
# 213336     TPS1  Level 2  ...  23:00:08.169  2019-08-01
# 213337     TPS1  Level 2  ...  23:00:08.461  2019-08-01
# 213338     TPS1  Level 2  ...  23:00:11.695  2019-08-01
# 213339     TPS1  Level 2  ...  23:00:11.695  2019-08-01
# 213340     TPS1  Level 2  ...  23:00:13.499  2019-08-01
# 213341     TPS1  Level 2  ...  23:00:14.148  2019-08-01
# 213342     TPS1  Level 2  ...  23:00:17.273  2019-08-01
# 213343     TPS1  Level 2  ...  23:00:18.321  2019-08-01
# 213344     TPS1  Level 2  ...  23:00:18.736  2019-08-01
# 213345     TPS1  Level 2  ...   23:00:20.19  2019-08-01
# 213347     TPS1  Level 2  ...   23:00:23.37  2019-08-01
# 213348     TPS1  Level 2  ...  23:00:23.573  2019-08-01
# 213349     TPS1  Level 2  ...  23:00:24.177  2019-08-01
# 213350     TPS1  Level 2  ...  23:00:24.225  2019-08-01
# 213351     TPS1  Level 2  ...   23:00:27.22  2019-08-01
# 213352     TPS1  Level 2  ...  23:00:28.161  2019-08-01
# ...

# %%
BBox = (t8.LNG.min(),   t8.LNG.max(),      
         t8.LAT.min(),  t8.LAT.max())
BBox
# Out:
# (-43.25185340249383,
#  -43.2497644862781,
#  -22.81218837988285,
#  -22.811386845135388)

# %%
print(type(BBox))
# Out:
# <class 'tuple'>

# %%
ruh_m = plt.imread('/content/gdrive/MyDrive/3 x Zones Group Assignment/map/map1.png')

# %%
fig, ax = plt.subplots(figsize = (20,20))
ax.scatter(t8.LNG, t8.LAT, zorder=1, alpha= 0.2, c='black', s=10)
ax.set_title('Plotting Data on TPS1 Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
